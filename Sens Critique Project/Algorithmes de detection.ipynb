# %% [markdown]
# # Imports

# %%
import pandas as pd
from igraph import *
import numpy as np
import matplotlib.pyplot as plt

# %%
g = Graph.Read_GML("graph_scouts_top_2000_reciproque.gml")

# %% [markdown]
# # Algorithme de Walktrap

# %%
res_walktrap=Graph.community_walktrap(g)

# %%
#plot(res_walktrap)

# %% [markdown]
# # Algorithme de Blondel & Louvain

# %%
res_louvain=Graph.community_multilevel(g)

# %%
#plot(res_louvain)

# %% [markdown]
# # Algorithme de Clauset

# %%
res_clauset=Graph.community_fastgreedy(g)

# %%
#plot(res_clauset)

# %% [markdown]
# # Algorithme de Newman

# %%
res_newman=Graph.community_edge_betweenness(g)

# %%
plot(res_newman)
